# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "api key"
)

completion = client.chat.completions.create(
  model="abacusai/dracarys-llama-3.1-70b-instruct",
  messages=[{"role":"user","content":"what is github ? and give all git commands"}],
  temperature=0.5,
  top_p=1,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")
# Out:
# **What is GitHub?**
#
#  platform for version control and collaboration on software development projects. It allows developers to host and manage their code repositories, track changes, and collaborate with others on a project. GitHub is built on top of the Git version control system, which is a distributed version control system that allows multiple developers to work on the same project simultaneously.
#
#  range of features, including:
#
#  A central location for storing and managing code.
#  **Version control**: Tracking changes to code, including who made the changes and when.
# ation**: Multiple developers can work on the same project simultaneously.
#  bugs, features, and other issues related to a project.
#  to review and merge changes from one branch to another.
# 6. **Code review**: A feature that allows developers to review and comment on each other's code.
#
# Git Commands**
#
# , organized by category:list of Git commands
#
# **Basic Git Commands**
#
# . `git init`: Initialize a new Git repository.
# 2. `git clone [url]`: Clone a Git repository from a URL.
#  [file]`: Add a file to the staging area.
#  in the current directory to the staging area.
#  `git commit -m "[message]"`: Commit changes with a meaningful message.
#  Display a log of all commits made to the repository.
# 7. `git status`: Display the current status of the repository.
#
# **Branching and Merging**
#
# . `git branch [branch-name]`: Create a new branch.
# ]`: Switch to a different branch.
# git merge [branch-name]`: Merge changes from one branch to another.
#  [branch-name]`: Delete a branch.
#  `git checkout -b [branch-name]`: Create a new branch and switch to it.
#
# itories**Repos
#
#  [url]`: Add a remote repository.
#  `git fetch [remote-name]`: Fetch changes from a remote repository.
# -name] [branch-name]`: Push changes to a remote repository.
# ] [branch-name]`: Pull changes from a remote repository.
#
# **Undoing Changes**
#
#  reset [file]`: Unstage a file.
# . `git reset --hard`: Reset the repository to the last commit.
# -hash]`: Revert a commit.
# git clean -f`: Remove untracked files.
#
# Tagging and Releasing**
#
#  [tag-name]`: Create a new tag.
# . `git tag -a [tag-name] -m "[message]"`: Create a new annotated tag.
# 3. `git tag -d [tag-name]`: Delete a tag.
# tag-name]`: Create a new release.
#
#  Git Commands**
#
#  [value]`: Set a configuration value.
#  `git config --global [key] [value]`: Set a global configuration value.
# git diff [file]`: Display differences between two versions of a file.
# ]`: Display the author and date of each line in a file.
# `: Search for a pattern in the repository.
#
#  This is not an exhaustive list of Git commands, but it covers most of the commonly used ones.
