# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

client = ChatNVIDIA(
  model="meta/llama-3.1-70b-instruct",
  api_key="api key", 
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
)

for chunk in client.stream([{"role":"user","content":"write a python code for sliding window protocol?"}]): 
  print(chunk.content, end="")
# Out:
# **Sliding Window Protocol Implementation in Python**
# ======================================================
#
# **Overview**
# ------------
#
#  over an unreliable communication link. It uses a sliding window to keep track of the packets that have been sent but not yet acknowledged.
#
# **Code**
# ------
#
# ```python
# import random
#
# class SlidingWindowProtocol:
# init__(self, window_size, packet_size):
#         """
#  Sliding Window Protocol.
#
#  sliding window.indow_size: The size of the
#         :param packet_size: The size of each packet.
#         """
#         self.window_size = window_size
#  packet_size.packet_size =
#         self.sent_packets = []
# _packets = []acknowledged
#
#     def send_packet(self, packet):
#         """
#  a packet.nd
#
#         :param packet: The packet to send.
#  """
#         self.sent_packets.append(packet)
# ) > self.window_size:ent_packets
#             self.sent_packets.pop(0)
#
#  def receive_ack(self, packet_number):
#         """
#  for a packet.e an acknowledgement
#
#  being acknowledged.t_number: The number of the packet
#         """
#         if packet_number in self.sent_packets:
#  self.acknowledged_packets.append(packet_number)
# (packet_number)f.sent_packets.remove
#
#     def get_unacknowledged_packets(self):
#         """
#         Get the packets that have not been acknowledged yet.
#
#  A list of unacknowledged packet numbers.
#         """
#  return [packet for packet in self.sent_packets if packet not in self.acknowledged_packets]
#
#     def is_window_full(self):
#         """
#  if the sliding window is full.
#
#  full, False otherwise.f the window is
#         """
# .window_sizern len(self.sent_packets) >= self
#
# # Example usage
# if __name__ == "__main__":
#     window_size = 5
#  packet_size = 1024
#
# , packet_size) SlidingWindowProtocol(window_size
#
#     # Send some packets
# 10):for i in range(
#         packet = f"Packet {i}"
# )       protocol.send_packet(packet
# : {packet}")t(f"Sent packet
#
#     # Receive some acknowledgements
#  in range(3):
# 9)      packet_number = random.randint(0,
#         protocol.receive_ack(packet_number)
#  for packet {packet_number}")owledgement
#
#     # Get unacknowledged packets
#     unacknowledged_packets = protocol.get_unacknowledged_packets()
#     print(f"Unacknowledged packets: {unacknowledged_packets}")
#
#     # Check if window is full
#  protocol.is_window_full()
# _window_full}")window full? {is
# ```
#
# **Explanation**
# --------------
#
#  Sliding Window Protocol with the following features:
#
# **: Packets are sent and stored in a list (`sent_packets`) until they are acknowledged.
#  received, the corresponding packet is removed from the `sent_packets` list and added to the `acknowledged_packets` list.
#  **Unacknowledged packet retrieval**: The `get_unacknowledged_packets` method returns a list of packet numbers that have not been acknowledged yet.
#  method checks if the sliding window is full by comparing the number of sent packets to the window size.
#
# **Example Use Cases**
# --------------------
#
#  **Reliable data transfer**: This protocol can be used to ensure reliable data transfer over an unreliable communication link.
#  Sliding Window Protocol can be used in network communication to manage packet transmission and acknowledgement.
#
#  edge cases or performance optimizations.tion and may not cover all
